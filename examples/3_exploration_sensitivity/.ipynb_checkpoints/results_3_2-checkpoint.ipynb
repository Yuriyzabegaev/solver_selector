# %%
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from pathlib import Path
from data_scripts import *
import pandas as pd


NUM_SIMS = 5
CONVERGED = False
USE_SIMULATED_TIME = False

# %%
data = {
    # "Standard exploration": load_data('../1/poro_dynamic', n_newest=NUM_SIMS),
    "Standard exploration": load_data("poro_eps_default", n_newest=NUM_SIMS),
    "No exploration": load_data("poro_eps0", n_newest=NUM_SIMS),
    "More exploration": load_data("poro_eps_big", n_newest=NUM_SIMS),
    "Random choice": load_data('../1/poro_lrandom', n_newest=NUM_SIMS)
    # "GP": load_data("poro_gp", n_newest=NUM_SIMS),
}

times_dict = dict()
for name, values in data.items():
    times_dict[name] = []
    for perf in values:
        res = np.sum(
            sum_per_time_step(
                make_solve_linear_system_time(perf, converged=CONVERGED),
                perf,
                converged=CONVERGED,
            )
        )
        times_dict[name].append(res)


times = pd.DataFrame.from_dict(times_dict).T
new_data = {
    'Worst': times.max(axis=1),
    'Mean': times.mean(axis=1),
    'Best': times.min(axis=1),
}
df_mandel = pd.DataFrame.from_dict(new_data)
df_mandel
# Out:
# Loading data:
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/performance/poro_eps_default_0.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/performance/poro_eps_default_1.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/performance/poro_eps_default_2.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/performance/poro_eps_default_3.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/performance/poro_eps_default_4.npy
# Loading data:
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/performance/poro_eps0_0.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/performance/poro_eps0_1.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/performance/poro_eps0_2.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/performance/poro_eps0_3.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/performance/poro_eps0_4.npy
# Loading data:
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/performance/poro_eps_big_0.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/performance/poro_eps_big_1.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/performance/poro_eps_big_2.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/performance/poro_eps_big_3.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/performance/poro_eps_big_4.npy
# Loading data:
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/../1/performance/poro_lrandom_0.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/../1/performance/poro_lrandom_1.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/../1/performance/poro_lrandom_2.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/../1/performance/poro_lrandom_3.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/../1/performance/poro_lrandom_4.npy
#                           Worst       Mean       Best
# Standard exploration  70.681621  70.236036  69.562186
# No exploration        67.169279  66.847898  66.254216
# More exploration      71.088978  70.848933  70.212629
# Random choice         89.348663  88.781150  88.578696

# %%
data = {
    "Standard from 1": load_data('../1/thermal_dynamic', n_newest=NUM_SIMS),
    "Standard exploration": load_data("thermal_eps_default", n_newest=NUM_SIMS),
    "No exploration": load_data("thermal_eps0", n_newest=NUM_SIMS),
    "More exploration": load_data("thermal_eps_big", n_newest=NUM_SIMS),
    "Random choice": load_data('../1/thermal_random', n_newest=NUM_SIMS)
    # "GP": load_data("thermal_gp", n_newest=NUM_SIMS),
}

times_dict = dict()
for name, values in data.items():
    times_dict[name] = []
    for perf in values:
        res = np.sum(
            sum_per_time_step(
                make_solve_linear_system_time(perf, converged=CONVERGED),
                perf,
                converged=CONVERGED,
            )
        )
        times_dict[name].append(res)


times = pd.DataFrame.from_dict(times_dict).T
new_data = {
    'Worst': times.max(axis=1),
    'Mean': times.mean(axis=1),
    'Best': times.min(axis=1),
}
df_thermal = pd.DataFrame.from_dict(new_data)
df_thermal
# Out:
# Loading data:
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/../1/performance/thermal_dynamic_0.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/../1/performance/thermal_dynamic_1.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/../1/performance/thermal_dynamic_2.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/../1/performance/thermal_dynamic_3.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/../1/performance/thermal_dynamic_4.npy
# Loading data:
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/performance/thermal_eps_default_0.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/performance/thermal_eps_default_1.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/performance/thermal_eps_default_2.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/performance/thermal_eps_default_3.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/performance/thermal_eps_default_4.npy
# Loading data:
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/performance/thermal_eps0_0.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/performance/thermal_eps0_1.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/performance/thermal_eps0_2.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/performance/thermal_eps0_3.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/performance/thermal_eps0_4.npy
# Loading data:
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/performance/thermal_eps_big_0.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/performance/thermal_eps_big_1.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/performance/thermal_eps_big_2.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/performance/thermal_eps_big_3.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/performance/thermal_eps_big_4.npy
# Loading data:
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/../1/performance/thermal_random_0.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/../1/performance/thermal_random_1.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/../1/performance/thermal_random_2.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/../1/performance/thermal_random_3.npy
# /home/porepy/solver_selector/examples/3_exploration_sensitivity/../1/performance/thermal_random_4.npy
#                            Worst        Mean        Best
# Standard from 1       111.294050  110.714257  110.095977
# Standard exploration  111.995642  111.093925  110.542088
# No exploration        131.230053  118.815619  109.384535
# More exploration      112.306357  111.404138  110.765527
# Random choice         217.858506  216.512424  215.962550

# %%
df = pd.concat((df_mandel, df_thermal), join='inner', axis=1, keys=("Mandel problem", "Thermal problem"))
df = df.style.highlight_min(axis=0, props="textbf:--rwrap;").format(precision=2)
df
# Out:
# <style type="text/css">
# #T_67ea8_row0_col3, #T_67ea8_row0_col4, #T_67ea8_row1_col0, #T_67ea8_row1_col1, #T_67ea8_row1_col2, #T_67ea8_row1_col5 {
#   textbf: --rwrap;
# }
# </style>
# <table id="T_67ea8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_67ea8_level0_col0" class="col_heading level0 col0" colspan="3">Mandel problem</th>
#       <th id="T_67ea8_level0_col3" class="col_heading level0 col3" colspan="3">Thermal problem</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_67ea8_level1_col0" class="col_heading level1 col0" >Worst</th>
#       <th id="T_67ea8_level1_col1" class="col_heading level1 col1" >Mean</th>
#       <th id="T_67ea8_level1_col2" class="col_heading level1 col2" >Best</th>
#       <th id="T_67ea8_level1_col3" class="col_heading level1 col3" >Worst</th>
#       <th id="T_67ea8_level1_col4" class="col_heading level1 col4" >Mean</th>
#       <th id="T_67ea8_level1_col5" class="col_heading level1 col5" >Best</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_67ea8_level0_row0" class="row_heading level0 row0" >Standard exploration</th>
#       <td id="T_67ea8_row0_col0" class="data row0 col0" >70.68</td>
#       <td id="T_67ea8_row0_col1" class="data row0 col1" >70.24</td>
#       <td id="T_67ea8_row0_col2" class="data row0 col2" >69.56</td>
#       <td id="T_67ea8_row0_col3" class="data row0 col3" >112.00</td>
#       <td id="T_67ea8_row0_col4" class="data row0 col4" >111.09</td>
#       <td id="T_67ea8_row0_col5" class="data row0 col5" >110.54</td>
#     </tr>
#     <tr>
#       <th id="T_67ea8_level0_row1" class="row_heading level0 row1" >No exploration</th>
#       <td id="T_67ea8_row1_col0" class="data row1 col0" >67.17</td>
#       <td id="T_67ea8_row1_col1" class="data row1 col1" >66.85</td>
#       <td id="T_67ea8_row1_col2" class="data row1 col2" >66.25</td>
#       <td id="T_67ea8_row1_col3" class="data row1 col3" >131.23</td>
#       <td id="T_67ea8_row1_col4" class="data row1 col4" >118.82</td>
#       <td id="T_67ea8_row1_col5" class="data row1 col5" >109.38</td>
#     </tr>
#     <tr>
#       <th id="T_67ea8_level0_row2" class="row_heading level0 row2" >More exploration</th>
#       <td id="T_67ea8_row2_col0" class="data row2 col0" >71.09</td>
#       <td id="T_67ea8_row2_col1" class="data row2 col1" >70.85</td>
#       <td id="T_67ea8_row2_col2" class="data row2 col2" >70.21</td>
#       <td id="T_67ea8_row2_col3" class="data row2 col3" >112.31</td>
#       <td id="T_67ea8_row2_col4" class="data row2 col4" >111.40</td>
#       <td id="T_67ea8_row2_col5" class="data row2 col5" >110.77</td>
#     </tr>
#     <tr>
#       <th id="T_67ea8_level0_row3" class="row_heading level0 row3" >Random choice</th>
#       <td id="T_67ea8_row3_col0" class="data row3 col0" >89.35</td>
#       <td id="T_67ea8_row3_col1" class="data row3 col1" >88.78</td>
#       <td id="T_67ea8_row3_col2" class="data row3 col2" >88.58</td>
#       <td id="T_67ea8_row3_col3" class="data row3 col3" >217.86</td>
#       <td id="T_67ea8_row3_col4" class="data row3 col4" >216.51</td>
#       <td id="T_67ea8_row3_col5" class="data row3 col5" >215.96</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(df.to_latex())
# Out:
# \begin{tabular}{lrrrrrr}
#  & \multicolumn{3}{r}{Mandel problem} & \multicolumn{3}{r}{Thermal problem} \\
#  & Worst & Mean & Best & Worst & Mean & Best \\
# Standard exploration & 70.68 & 70.24 & 69.56 & \textbf{112.00} & \textbf{111.09} & 110.54 \\
# No exploration & \textbf{67.17} & \textbf{66.85} & \textbf{66.25} & 131.23 & 118.82 & \textbf{109.38} \\
# More exploration & 71.09 & 70.85 & 70.21 & 112.31 & 111.40 & 110.77 \\
# Random choice & 89.35 & 88.78 & 88.58 & 217.86 & 216.51 & 215.96 \\
# \end{tabular}
